# %%
import os
import numpy as np
import pandas as pd
import plotly as py
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objs as go
import contextily as ctx
import matplotlib.image as mpimg
import matplotlib
from plotly.subplots import make_subplots
from plotly.offline import download_plotlyjs 
from plotly.offline import init_notebook_mode
from plotly.offline import plot,iplot
init_notebook_mode(connected=True)
import seaborn as sns
import geos
import mpl_toolkits
from matplotlib.animation import FuncAnimation
from matplotlib import animation, rc
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data=pd.read_csv('Road accidents data/only_road_accidents_data3.csv')

# %%
data.head()
# Out:
#         STATE/UT  YEAR  0-3 hrs. (Night)  3-6 hrs. (Night)  6-9 hrs (Day)  \
# 0  A & N Islands  2001                 2                 6             29
# 1  A & N Islands  2002                 2                 6             22
# 2  A & N Islands  2003                 2                 8             31
# 3  A & N Islands  2004                 2                 5             29
# 4  A & N Islands  2005                 0                 8             27
#
#    9-12 hrs (Day)  12-15 hrs (Day)  15-18 hrs (Day)  18-21 hrs (Night)  \
# 0              40               39               40                 18
# 1              41               33               33                 23
# 2              35               28               36                 25
# 3              42               43               43                 37
# 4              28               38               42                 50
#
#    21-24 hrs (Night)  Total
# 0                  7    181
# 1                  8    168
# 2                 15    180
# 3                 14    215
# 4                 13    206

# %%
data_by_states=data.loc[:,['STATE/UT','YEAR','Total']]

# %%
data_by_states.head()
# Out:
#         STATE/UT  YEAR  Total
# 0  A & N Islands  2001    181
# 1  A & N Islands  2002    168
# 2  A & N Islands  2003    180
# 3  A & N Islands  2004    215
# 4  A & N Islands  2005    206

# %%
df1=data_by_states.drop('YEAR',axis=1)
df1.head()
# Out:
#         STATE/UT  Total
# 0  A & N Islands    181
# 1  A & N Islands    168
# 2  A & N Islands    180
# 3  A & N Islands    215
# 4  A & N Islands    206

# %%
df1=df1.groupby('STATE/UT').sum().reset_index().sort_values(by='Total',ascending=False)

# %%
df1.head()
# Out:
#           STATE/UT   Total
# 30      Tamil Nadu  852073
# 20     Maharashtra  641614
# 16       Karnataka  584761
# 1   Andhra Pradesh  546821
# 17          Kerala  518161

# %% [markdown]
# Above are the total number of road accidents from 2001-2014

# %%
plt.figure(figsize=(20,10))

sns.barplot(x=df1['STATE/UT'],y=df1['Total'],palette='rainbow')
plt.xticks(rotation=90)

plt.title('Cases of road accidents in each state/UT from 2001-14',size=20)
# Out:
# Text(0.5, 1.0, 'Cases of road accidents in each state/UT from 2001-14')

# %% [markdown]
# A visual representation of all the road accidents in the states

# %%
df_top=df1[df1['Total']>300000]
df_top
# Out:
#           STATE/UT   Total
# 30      Tamil Nadu  852073
# 20     Maharashtra  641614
# 16       Karnataka  584761
# 1   Andhra Pradesh  546821
# 17          Kerala  518161
# 19  Madhya Pradesh  394007
# 28       Rajasthan  323653
# 11         Gujarat  300325

# %%
plt.figure(figsize=(20,10))
sns.barplot(x=df_top['STATE/UT'],y=df_top['Total'],palette='gnuplot_d')
plt.xticks(size=15,rotation=45)
plt.yticks(size=10)

plt.title('States with highest road accidents between 2001-14',size=20)
# Out:
# Text(0.5, 1.0, 'States with highest road accidents between 2001-14')

# %% [markdown]
# The above states have each had above or equal to 3 lakh road accident cases.

# %%
df_year=data_by_states.groupby('YEAR').sum().reset_index()

# %%
df_year
# Out:
#     YEAR   Total
# 0   2001  323720
# 1   2002  335707
# 2   2003  336468
# 3   2004  361343
# 4   2005  390378
# 5   2006  394432
# 6   2007  418657
# 7   2008  415855
# 8   2009  421628
# 9   2010  430654
# 10  2011  440123
# 11  2012  440042
# 12  2013  443001
# 13  2014  450898

# %%
df_year['Percentage change']=df_year['Total'].pct_change().round(2)
df_year
# Out:
#     YEAR   Total  Percentage change
# 0   2001  323720                NaN
# 1   2002  335707               0.04
# 2   2003  336468               0.00
# 3   2004  361343               0.07
# 4   2005  390378               0.08
# 5   2006  394432               0.01
# 6   2007  418657               0.06
# 7   2008  415855              -0.01
# 8   2009  421628               0.01
# 9   2010  430654               0.02
# 10  2011  440123               0.02
# 11  2012  440042              -0.00
# 12  2013  443001               0.01
# 13  2014  450898               0.02

# %%
plt.figure(figsize=(20,10))

plt.plot(df_year['YEAR'],df_year['Total'], color='indianred')
plt.title('Number of road accidents in India on a yearly basis',size=20)
plt.xlabel('Year',size=15)
plt.ylabel('Number of accidents',size=15)
plt.xticks(np.arange(2001,2015,1),size=10)
# Out:
# ([<matplotlib.axis.XTick at 0x7fa86bf70150>,
#   <matplotlib.axis.XTick at 0x7fa86bf70110>,
#   <matplotlib.axis.XTick at 0x7fa86bf6ec90>,
#   <matplotlib.axis.XTick at 0x7fa86bf9ca50>,
#   <matplotlib.axis.XTick at 0x7fa86bf9c8d0>,
#   <matplotlib.axis.XTick at 0x7fa86bfa4510>,
#   <matplotlib.axis.XTick at 0x7fa86bfa4a90>,
#   <matplotlib.axis.XTick at 0x7fa86bfa4fd0>,
#   <matplotlib.axis.XTick at 0x7fa86bf9c910>,
#   <matplotlib.axis.XTick at 0x7fa86bfac490>,
#   <matplotlib.axis.XTick at 0x7fa86bfac990>,
#   <matplotlib.axis.XTick at 0x7fa86bfaced0>,
#   <matplotlib.axis.XTick at 0x7fa86bfb6450>,
#   <matplotlib.axis.XTick at 0x7fa86bfb6990>],
#  <a list of 14 Text major ticklabel objects>)

# %% [markdown]
# The above data shows that there is a positive increase of road accidents each year.

# %%
plt.figure(figsize=(20,10))
sns.barplot(x=df_year['YEAR'],y=df_year['Percentage change'],palette='viridis')
plt.xlabel('Year',size=15)
plt.ylabel('Perncentage Change',size=15)
plt.yticks(np.arange(-0.02,0.09,0.01))
# Out:
# ([<matplotlib.axis.YTick at 0x7fa86c005650>,
#   <matplotlib.axis.YTick at 0x7fa86c004e50>,
#   <matplotlib.axis.YTick at 0x7fa86c0023d0>,
#   <matplotlib.axis.YTick at 0x7fa86c375490>,
#   <matplotlib.axis.YTick at 0x7fa86c3759d0>,
#   <matplotlib.axis.YTick at 0x7fa86c375f10>,
#   <matplotlib.axis.YTick at 0x7fa86c37a4d0>,
#   <matplotlib.axis.YTick at 0x7fa86c37aa10>,
#   <matplotlib.axis.YTick at 0x7fa86c37a8d0>,
#   <matplotlib.axis.YTick at 0x7fa86c3834d0>,
#   <matplotlib.axis.YTick at 0x7fa86c3839d0>],
#  <a list of 11 Text major ticklabel objects>)

# %% [markdown]
# From the above plots, it can be seen that apart from the year 2008, every other has recorded an increase or the same number of accidents in the country

# %%
plt.figure(figsize=(20,10))

plt.plot(df_year['YEAR'],df_year['Total'], color='indianred')
plt.title('Number of road accidents in India on a yearly basis',size=20)
plt.xlabel('Year',size=15)
plt.ylabel('Number of accidents',size=15)
plt.xticks(np.arange(2001,2015,1),size=10)
# Out:
# ([<matplotlib.axis.XTick at 0x7fa86c3bf950>,
#   <matplotlib.axis.XTick at 0x7fa86c3bf910>,
#   <matplotlib.axis.XTick at 0x7fa86c3bf5d0>,
#   <matplotlib.axis.XTick at 0x7fa86c3e5f10>,
#   <matplotlib.axis.XTick at 0x7fa86c7c6550>,
#   <matplotlib.axis.XTick at 0x7fa86c7c6a90>,
#   <matplotlib.axis.XTick at 0x7fa86c7c60d0>,
#   <matplotlib.axis.XTick at 0x7fa86c3e5e90>,
#   <matplotlib.axis.XTick at 0x7fa86c7cd650>,
#   <matplotlib.axis.XTick at 0x7fa86c7cdb90>,
#   <matplotlib.axis.XTick at 0x7fa86c7cdd50>,
#   <matplotlib.axis.XTick at 0x7fa86c7d6610>,
#   <matplotlib.axis.XTick at 0x7fa86c7d6b50>,
#   <matplotlib.axis.XTick at 0x7fa86c7d6d10>],
#  <a list of 14 Text major ticklabel objects>)

# %%
from sklearn.linear_model import LinearRegression

# %%
x_matrix=df_year['YEAR'].values.reshape(-1,1)
y=df_year['Total'].values

# %%
reg=LinearRegression()
reg.fit(x_matrix,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
reg.intercept_
# Out:
# -19883660.67032967

# %%
reg.coef_
# Out:
# array([10104.04395604])

# %%
regression=[]
a=np.arange(2015,2025)
for year in a:
    year=np.array([year])
    year=year.reshape(1,-1)
    regression.append(reg.predict(year))

# %%
df_predicted=pd.DataFrame(regression)

# %%
df_predicted=df_predicted.rename(columns={0:'Total'})

# %%
df_predicted.reset_index(drop=True,inplace=True)

# %%
years=np.arange(2015,2025,1)

# %%
df_temp=pd.DataFrame(years)
df_temp
# Out:
#       0
# 0  2015
# 1  2016
# 2  2017
# 3  2018
# 4  2019
# 5  2020
# 6  2021
# 7  2022
# 8  2023
# 9  2024

# %%
df_predicted['Year']=df_temp

# %%
df_predicted=df_predicted[['Year','Total']]

# %%
df_predicted['Total']=df_predicted['Total'].values.round(0)
df_predicted.index=df_predicted.index+1
df_predicted
# Out:
#     Year     Total
# 1   2015  475988.0
# 2   2016  486092.0
# 3   2017  496196.0
# 4   2018  506300.0
# 5   2019  516404.0
# 6   2020  526508.0
# 7   2021  536612.0
# 8   2022  546716.0
# 9   2023  556820.0
# 10  2024  566924.0

# %% [markdown]
# Using linear regression of the past data from 2001-2014, we can predict the values of future years as given above.

# %%
df_location=pd.read_csv('Road accidents data/Acc_classified_according_to_Type_of_Location_2014_and_2016.csv')

# %%
df_location.head()
# Out:
#   S. No.          State/ UT  Near School or College - Total Acc. - 2014  \
# 0      1     Andhra Pradesh                                      1110.0
# 1      2  Arunachal Pradesh                                        23.0
# 2      3              Assam                                       409.0
# 3      4              Bihar                                       699.0
# 4      5       Chhattisgarh                                       577.0
#
#    Near School or College - Persons Killed - 2014  \
# 0                                           301.0
# 1                                             8.0
# 2                                           157.0
# 3                                           342.0
# 4                                           162.0
#
#    Near School or College - Persons Injured - 2014  \
# 0                                           1486.0
# 1                                             48.0
# 2                                            348.0
# 3                                            517.0
# 4                                            579.0
#
#    Near or inside a village - Total Acc. - 2014  \
# 0                                        3782.0
# 1                                           0.0
# 2                                         792.0
# 3                                        2050.0
# 4                                        3444.0
#
#    Near or inside a village - Persons Killed - 2014  \
# 0                                            1255.0
# 1                                               0.0
# 2                                             296.0
# 3                                            1064.0
# 4                                            1160.0
#
#    Near or inside a village - Persons Injured - 2014  \
# 0                                             4762.0
# 1                                                0.0
# 2                                              716.0
# 3                                             1443.0
# 4                                             3470.0
#
#    Near a Factory/Industrial area - Total Acc. - 2014  \
# 0                                              830.0
# 1                                                0.0
# 2                                              364.0
# 3                                              349.0
# 4                                              658.0
#
#    Near a Factory/Industrial area - Persons Killed - 2014  ...  \
# 0                                              277.0       ...
# 1                                                0.0       ...
# 2                                              123.0       ...
# 3                                              161.0       ...
# 4                                              220.0       ...
#
#    Near Petrol Pump - Persons Injured - 2016  \
# 0                                       1030
# 1                                         13
# 2                                        254
# 3                                        232
# 4                                        445
#
#    Near Bus Stand - Total Accidents - 2016  \
# 0                                     1151
# 1                                        3
# 2                                      367
# 3                                      336
# 4                                      438
#
#    Near Bus Stand - Persons Killed - 2016  \
# 0                                     373
# 1                                       0
# 2                                     114
# 3                                     197
# 4                                     111
#
#    Near Bus Stand - Persons Injured - 2016  \
# 0                                     1409
# 1                                       11
# 2                                      285
# 3                                      250
# 4                                      409
#
#    Near or on Road under Construction - Total Accidents - 2016  \
# 0                                                389
# 1                                                 15
# 2                                                254
# 3                                                272
# 4                                                396
#
#    Near or on Road under Construction - Persons Killed - 2016  \
# 0                                                199
# 1                                                 16
# 2                                                 69
# 3                                                130
# 4                                                 97
#
#    Near or on Road under Construction - Persons Injured - 2016  \
# 0                                                572
# 1                                                 39
# 2                                                231
# 3                                                179
# 4                                                340
#
#    Open Area - Total Accidents - 2016  Open Area - Persons Killed - 2016  \
# 0                              9912.0                               3486
# 1                                78.0                                 50
# 2                              2614.0                                955
# 3                              2806.0                               1839
# 4                              5716.0                               1982
#
#    Open Area - Persons Injured - 2016
# 0                               12723
# 1                                  53
# 2                                2220
# 3                                1930
# 4                                5837
#
# [5 rows x 86 columns]

# %%
df_location_updated=df_location.iloc[:,47:]
df_location_updated.head()
# Out:
#    Near School/College/any other educational Institutes - Total Accidents - 2016  \
# 0                                               1393
# 1                                                 15
# 2                                                488
# 3                                                667
# 4                                                648
#
#    Near School/College/any other educational Institutes - Persons Killed - 2016  \
# 0                                                451
# 1                                                  9
# 2                                                153
# 3                                                369
# 4                                                155
#
#    Near School/College/any other educational Institutes - Persons Injured - 2016  \
# 0                                               1604
# 1                                                 37
# 2                                                334
# 3                                                444
# 4                                                587
#
#    Pedestrian crossing - Total Accidents - 2016  \
# 0                                          2026
# 1                                            10
# 2                                           505
# 3                                           573
# 4                                           320
#
#    Pedestrian crossing - Persons Killed - 2016  \
# 0                                          777
# 1                                            3
# 2                                          174
# 3                                          340
# 4                                           81
#
#    Pedestrian crossing - Persons Injured - 2016  \
# 0                                          2269
# 1                                            31
# 2                                           406
# 3                                           308
# 4                                           282
#
#    Market Place - Total Accidents - 2016  \
# 0                                    842
# 1                                     18
# 2                                    667
# 3                                    787
# 4                                   1027
#
#    Market Place - Persons Killed - 2016  \
# 0                                   272
# 1                                     0
# 2                                   235
# 3                                   420
# 4                                   280
#
#    Market Place - Persons Injured - 2016  \
# 0                                   1016
# 1                                     27
# 2                                    464
# 3                                    589
# 4                                    874
#
#    Near Office Complex - Total Accidents - 2016  ...  \
# 0                                           844  ...
# 1                                            17  ...
# 2                                           326  ...
# 3                                           196  ...
# 4                                           595  ...
#
#    Near Petrol Pump - Persons Injured - 2016  \
# 0                                       1030
# 1                                         13
# 2                                        254
# 3                                        232
# 4                                        445
#
#    Near Bus Stand - Total Accidents - 2016  \
# 0                                     1151
# 1                                        3
# 2                                      367
# 3                                      336
# 4                                      438
#
#    Near Bus Stand - Persons Killed - 2016  \
# 0                                     373
# 1                                       0
# 2                                     114
# 3                                     197
# 4                                     111
#
#    Near Bus Stand - Persons Injured - 2016  \
# 0                                     1409
# 1                                       11
# 2                                      285
# 3                                      250
# 4                                      409
#
#    Near or on Road under Construction - Total Accidents - 2016  \
# 0                                                389
# 1                                                 15
# 2                                                254
# 3                                                272
# 4                                                396
#
#    Near or on Road under Construction - Persons Killed - 2016  \
# 0                                                199
# 1                                                 16
# 2                                                 69
# 3                                                130
# 4                                                 97
#
#    Near or on Road under Construction - Persons Injured - 2016  \
# 0                                                572
# 1                                                 39
# 2                                                231
# 3                                                179
# 4                                                340
#
#    Open Area - Total Accidents - 2016  Open Area - Persons Killed - 2016  \
# 0                              9912.0                               3486
# 1                                78.0                                 50
# 2                              2614.0                                955
# 3                              2806.0                               1839
# 4                              5716.0                               1982
#
#    Open Area - Persons Injured - 2016
# 0                               12723
# 1                                  53
# 2                                2220
# 3                                1930
# 4                                5837
#
# [5 rows x 39 columns]

# %%
df_month=pd.read_csv('Road accidents data/only_road_accidents_data_month2.csv')

# %%
df_month.head()
# Out:
#         STATE/UT  YEAR  JANUARY  FEBRUARY  MARCH  APRIL  MAY  JUNE  JULY  \
# 0  A & N Islands  2001        8        23     15     15   14    19    14
# 1  A & N Islands  2002       12        10     14     16   10     7    16
# 2  A & N Islands  2003       19        13     15     13   13    12     8
# 3  A & N Islands  2004       21        14     22     17   13    18    16
# 4  A & N Islands  2005       19        21     22     17   13    19    21
#
#    AUGUST  SEPTEMBER  OCTOBER  NOVEMBER  DECEMBER  TOTAL
# 0      19          7       12        13        22    181
# 1      11         23       21        11        17    168
# 2      16         17       25        14        15    180
# 3      19         16       20        15        24    215
# 4      14         15       19        10        16    206

# %%
i=0
for year in df_month['YEAR']:
    if year==2014:
        i+=1
    else:
        df_month=df_month.drop(i)
        i+=1

# %%
df_month.reset_index(drop=True)
# Out:
#              STATE/UT  YEAR  JANUARY  FEBRUARY  MARCH  APRIL   MAY  JUNE  \
# 0       A & N Islands  2014       25        13     19     19    18    15
# 1      Andhra Pradesh  2014     3809      3657   3641   3582  3986  3664
# 2   Arunachal Pradesh  2014       28        10     10     21     9    12
# 3               Assam  2014      658       615    689    612   566   531
# 4               Bihar  2014      777       742    852    714   985  1002
# 5          Chandigarh  2014       35        22     31     40    32    25
# 6        Chhattisgarh  2014     1167      1110   1000   1020  1149  1051
# 7          D&N Haveli  2014        6         7      7     10     9     4
# 8         Daman & Diu  2014        6         4      3      3     2     2
# 9            Delhi Ut  2014      643       698    801    632   661   658
# 10                Goa  2014      433       359    349    349   367   354
# 11            Gujarat  2014     2023      1978   2039   1846  2127  1988
# 12            Haryana  2014      892       881    963    911   939   906
# 13   Himachal Pradesh  2014      246       191    260    234   289   295
# 14    Jammu & Kashmir  2014      414       415    424    433   506   594
# 15          Jharkhand  2014      399       434    418    425   454   414
# 16          Karnataka  2014     3915      3649   3805   3577  4053  3772
# 17             Kerala  2014     3332      2909   3005   2785  3162  2805
# 18        Lakshadweep  2014        0         0      0      0     0     0
# 19     Madhya Pradesh  2014     3375      3154   3470   3345  4107  3637
# 20        Maharashtra  2014     3978      3714   3920   3847  4258  3784
# 21            Manipur  2014       61        59     66     59    62    49
# 22          Meghalaya  2014       30        27     20     25    27    28
# 23            Mizoram  2014       10         6     15     10    11     4
# 24           Nagaland  2014        3         2      2      4     2     0
# 25             Odisha  2014      896       826    851    726   852   828
# 26         Puducherry  2014       44        64     65     46    59    57
# 27             Punjab  2014      495       493    555    524   563   535
# 28          Rajasthan  2014     2143      1951   2130   2053  2484  2213
# 29             Sikkim  2014        9         6     15     13    13    11
# 30         Tamil Nadu  2014     5658      5293   5824   5303  5711  5915
# 31            Tripura  2014       65        74     81     63    72    46
# 32      Uttar Pradesh  2014     2550      2311   2217   2067  2265  2209
# 33        Uttarakhand  2014       58        43     65     64    77    62
# 34        West Bengal  2014     1516      1398   1473   1385  1527  1439
#
#     JULY  AUGUST  SEPTEMBER  OCTOBER  NOVEMBER  DECEMBER  TOTAL
# 0     15      16         15       23        18        22    218
# 1   3167    3587       3225     3410      3346      4158  43232
# 2     13      14         14       15        22        17    185
# 3    573     528        460      670       638       604   7144
# 4    757     662        685      720       829       806   9531
# 5     22      32         38       31        28        30    366
# 6    934     877        910     1005       973       944  12140
# 7      8       7          7        8         8         6     87
# 8      0       5          1        5         2         6     39
# 9    624     744        742      687       720       700   8310
# 10   322     324        285      312       354       422   4230
# 11  1673    1633       1506     1817      1678      1844  22152
# 12   955     916        871      891       962       956  11043
# 13   292     329        272      302       313       302   3325
# 14   563     515        415      544       517       438   5778
# 15   391     384        341      419       373       453   4905
# 16  3421    3428       3254     3517      3442      3861  43694
# 17  2834    2913       2911     2911      2963      3342  35872
# 18     0       0          0        1         0         0      1
# 19  3104    2951       2946     3261      3288      3060  39698
# 20  3546    3450       3298     3291      3478      3818  44382
# 21    49      53         73       72        59        73    735
# 22    29      24         26       22        19        24    301
# 23    10       5          6        3         7         8     95
# 24     1       3          0        4         0         7     28
# 25   756     693        660      776       854       922   9640
# 26    60      58         62       75        44        37    671
# 27   491     519        489      568       595       564   6391
# 28  1976    1888       1839     2035      2104      1823  24639
# 29    14      11         19        6         9         4    130
# 30  5719    5936       5777     5516      5036      5562  67250
# 31    64      53         54       60        38        46    716
# 32  2086    2017       1824     2023      2170      2325  26064
# 33    61      72         69       83        76        71    801
# 34  1416    1356       1391     1395      1415      1394  17105

# %%
df_month_top=df_month[df_month['TOTAL']>20000]
df_month_top
# Out:
#            STATE/UT  YEAR  JANUARY  FEBRUARY  MARCH  APRIL   MAY  JUNE  JULY  \
# 27   Andhra Pradesh  2014     3809      3657   3641   3582  3986  3664  3167
# 167         Gujarat  2014     2023      1978   2039   1846  2127  1988  1673
# 237       Karnataka  2014     3915      3649   3805   3577  4053  3772  3421
# 251          Kerala  2014     3332      2909   3005   2785  3162  2805  2834
# 279  Madhya Pradesh  2014     3375      3154   3470   3345  4107  3637  3104
# 293     Maharashtra  2014     3978      3714   3920   3847  4258  3784  3546
# 405       Rajasthan  2014     2143      1951   2130   2053  2484  2213  1976
# 433      Tamil Nadu  2014     5658      5293   5824   5303  5711  5915  5719
# 461   Uttar Pradesh  2014     2550      2311   2217   2067  2265  2209  2086
#
#      AUGUST  SEPTEMBER  OCTOBER  NOVEMBER  DECEMBER  TOTAL
# 27     3587       3225     3410      3346      4158  43232
# 167    1633       1506     1817      1678      1844  22152
# 237    3428       3254     3517      3442      3861  43694
# 251    2913       2911     2911      2963      3342  35872
# 279    2951       2946     3261      3288      3060  39698
# 293    3450       3298     3291      3478      3818  44382
# 405    1888       1839     2035      2104      1823  24639
# 433    5936       5777     5516      5036      5562  67250
# 461    2017       1824     2023      2170      2325  26064

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='STATE/UT',y='TOTAL',data=df_month_top,palette='winter')
plt.xlabel('State/UT',size=15)
plt.ylabel('Total accidents',size=15)
plt.title('States with highest accidents in 2014',size=25)
# Out:
# Text(0.5, 1.0, 'States with highest accidents in 2014')

# %% [markdown]
# As we see, like each year, Tamil Nadu records highest number of road accidents by a large margin.

# %%
df_tamil_nadu=df_month.loc[df_month['STATE/UT'].isin(['Tamil Nadu'])]
df_karnataka=df_month.loc[df_month['STATE/UT'].isin(['Karnataka'])]
df_maharashtra=df_month.loc[df_month['STATE/UT'].isin(['Maharashtra'])]
df_delhi=df_month.loc[df_month['STATE/UT'].isin(['Delhi Ut'])]

# %%
df_tamil_nadu
# Out:
#        STATE/UT  YEAR  JANUARY  FEBRUARY  MARCH  APRIL   MAY  JUNE  JULY  \
# 433  Tamil Nadu  2014     5658      5293   5824   5303  5711  5915  5719
#
#      AUGUST  SEPTEMBER  OCTOBER  NOVEMBER  DECEMBER  TOTAL
# 433    5936       5777     5516      5036      5562  67250

# %%
df_delhi
# Out:
#      STATE/UT  YEAR  JANUARY  FEBRUARY  MARCH  APRIL  MAY  JUNE  JULY  AUGUST  \
# 139  Delhi Ut  2014      643       698    801    632  661   658   624     744
#
#      SEPTEMBER  OCTOBER  NOVEMBER  DECEMBER  TOTAL
# 139        742      687       720       700   8310

# %%
df_karnataka
# Out:
#       STATE/UT  YEAR  JANUARY  FEBRUARY  MARCH  APRIL   MAY  JUNE  JULY  \
# 237  Karnataka  2014     3915      3649   3805   3577  4053  3772  3421
#
#      AUGUST  SEPTEMBER  OCTOBER  NOVEMBER  DECEMBER  TOTAL
# 237    3428       3254     3517      3442      3861  43694

# %%
df_maharashtra
# Out:
#         STATE/UT  YEAR  JANUARY  FEBRUARY  MARCH  APRIL   MAY  JUNE  JULY  \
# 293  Maharashtra  2014     3978      3714   3920   3847  4258  3784  3546
#
#      AUGUST  SEPTEMBER  OCTOBER  NOVEMBER  DECEMBER  TOTAL
# 293    3450       3298     3291      3478      3818  44382

# %%
plt.figure(figsize=(20,10))
val=df_maharashtra.iloc[:,1:14].values
plt.plot(val[0],color='indianred',linewidth=3)
plt.xlim(1,13)
plt.ylim(3000,4500)
plt.xlabel('Month',size=15)
plt.ylabel('Number of accidents',size=15)
plt.title('Number of accidents on monthly basis in Maharshtra (2014)',size=25)
plt.xticks(np.arange(1,13))
# Out:
# ([<matplotlib.axis.XTick at 0x7fa866a90450>,
#   <matplotlib.axis.XTick at 0x7fa866a90410>,
#   <matplotlib.axis.XTick at 0x7fa866a8ff90>,
#   <matplotlib.axis.XTick at 0x7fa866ab7e10>,
#   <matplotlib.axis.XTick at 0x7fa866abe390>,
#   <matplotlib.axis.XTick at 0x7fa866abe8d0>,
#   <matplotlib.axis.XTick at 0x7fa866abee50>,
#   <matplotlib.axis.XTick at 0x7fa8629443d0>,
#   <matplotlib.axis.XTick at 0x7fa862944910>,
#   <matplotlib.axis.XTick at 0x7fa862944e50>,
#   <matplotlib.axis.XTick at 0x7fa86294b390>,
#   <matplotlib.axis.XTick at 0x7fa862944990>],
#  <a list of 12 Text major ticklabel objects>)

# %%
plt.figure(figsize=(20,10))
val=df_karnataka.iloc[:,1:14].values
plt.plot(val[0],color='green',linewidth=3)
plt.xlim(1,13)
plt.ylim(3000,4500)
plt.xlabel('Month',size=15)
plt.ylabel('Number of accidents',size=15)
plt.title('Number of accidents on monthly basis in Karnataka (2014)',size=25)
plt.xticks(np.arange(1,13))
# Out:
# ([<matplotlib.axis.XTick at 0x7fa86e03e310>,
#   <matplotlib.axis.XTick at 0x7fa86b70c290>,
#   <matplotlib.axis.XTick at 0x7fa86b705e10>,
#   <matplotlib.axis.XTick at 0x7fa86b733850>,
#   <matplotlib.axis.XTick at 0x7fa86b733d90>,
#   <matplotlib.axis.XTick at 0x7fa86b737310>,
#   <matplotlib.axis.XTick at 0x7fa86b737890>,
#   <matplotlib.axis.XTick at 0x7fa86b737dd0>,
#   <matplotlib.axis.XTick at 0x7fa86b737d10>,
#   <matplotlib.axis.XTick at 0x7fa86b7337d0>,
#   <matplotlib.axis.XTick at 0x7fa86b740610>,
#   <matplotlib.axis.XTick at 0x7fa86b740b50>],
#  <a list of 12 Text major ticklabel objects>)

# %% [markdown]
# In the states of Karnataka and Maharashtra, the accidents peak in the period of April to June. In the rainy seasons starting from first week of June, the accidents reduce. It could mean that drivers take greater precaution during the rains than the dry season.

# %%
plt.figure(figsize=(20,10))
val=df_tamil_nadu.iloc[:,1:14].values
plt.plot(val[0],color='purple',linewidth=3)
plt.xlim(1,13)
plt.ylim(5000,6000)
plt.xticks(np.arange(1,13))
plt.xlabel('Month',size=15)
plt.ylabel('Number of accidents',size=15)
plt.title('Number of accidents on monthly basis in Tamil Nadu (2014)',size=25)
# Out:
# Text(0.5, 1.0, 'Number of accidents on monthly basis in Tamil Nadu (2014)')

# %% [markdown]
# In Tamil Nadu aswell, the accidents become lowest during the peak rainy months which last from October to December.

# %%
plt.figure(figsize=(20,10))
val=df_delhi.iloc[:,1:14].values
plt.plot(val[0],color='black',linewidth=3)
plt.xlim(1,13)
plt.ylim(600,850)
plt.xlabel('Month',size=15)
plt.ylabel('Number of accidents',size=15)
plt.title('Number of accidents on monthly basis in New Delhi (2014)',size=25)
plt.xticks(np.arange(1,13))
# Out:
# ([<matplotlib.axis.XTick at 0x7fa84ef46390>,
#   <matplotlib.axis.XTick at 0x7fa84ef46350>,
#   <matplotlib.axis.XTick at 0x7fa84ef4ff10>,
#   <matplotlib.axis.XTick at 0x7fa84ef72b90>,
#   <matplotlib.axis.XTick at 0x7fa84ef72ad0>,
#   <matplotlib.axis.XTick at 0x7fa8502cd6d0>,
#   <matplotlib.axis.XTick at 0x7fa8502cd910>,
#   <matplotlib.axis.XTick at 0x7fa8502cde10>,
#   <matplotlib.axis.XTick at 0x7fa8502d5390>,
#   <matplotlib.axis.XTick at 0x7fa8502d58d0>,
#   <matplotlib.axis.XTick at 0x7fa8502d5dd0>,
#   <matplotlib.axis.XTick at 0x7fa8502dc350>],
#  <a list of 12 Text major ticklabel objects>)

# %% [markdown]
# In New Delhi, accidents seem to peak early in the year. As expected, the accidents during the rainy season from June to July are low. However, a sharp increase does take place in August.

# %%
df_hedu=pd.read_csv('Road accidents data/Accidents_Acc_EduQual_Drivers_above_10_Standard_09-16.csv')
df_hedu
# Out:
#                    States/UTs      2009      2010      2011      2012  \
# 0              Andhra Pradesh    9826.0    7849.0   20150.0    8144.0
# 1           Arunachal Pradesh      96.0      89.0      86.0      87.0
# 2                       Assam    2070.0       NaN       NaN       NaN
# 3                       Bihar    2447.0    3084.0    3810.0    3722.0
# 4                Chhattisgarh    3605.0    4569.0    4934.0    3571.0
# 5                         Goa    1934.0    2034.0    2215.0    2184.0
# 6                     Gujarat    8687.0    9611.0    9446.0    7132.0
# 7                     Haryana    4854.0    4682.0    4636.0    4112.0
# 8            Himachal Pradesh    1363.0    1317.0     717.0     977.0
# 9             Jammu & Kashmir    1024.0    1458.0     861.0     434.0
# 10                  Jharkhand    1475.0     900.0    1424.0    1037.0
# 11                  Karnataka   17774.0   20070.0   18410.0   18566.0
# 12                     Kerala   16795.0   16612.0   16884.0   17323.0
# 13             Madhya Pradesh   14382.0   18189.0   20207.0   19354.0
# 14                Maharashtra   19808.0   11355.0   10786.0   10538.0
# 15                    Manipur     194.0      47.0     428.0     171.0
# 16                  Meghalaya     128.0      84.0     146.0     119.0
# 17                    Mizoram      11.0      31.0      32.0      25.0
# 18                   Nagaland      23.0       2.0      16.0      18.0
# 19                     Odisha    3244.0    3644.0    4663.0    4284.0
# 20                     Punjab    1255.0    1441.0    1717.0    1825.0
# 21                  Rajasthan    7452.0    7605.0    6792.0    5475.0
# 22                     Sikkim     215.0      49.0     166.0       8.0
# 23                 Tamil Nadu   29260.0   29890.0   32655.0   29871.0
# 24                  Telangana       NaN       NaN       NaN       NaN
# 25                    Tripura     286.0     205.0     379.0     222.0
# 26                Uttarakhand     734.0     263.0     713.0     456.0
# 27              Uttar Pradesh   10361.0   10895.0   10782.0   10995.0
# 28                West Bengal     718.0     494.0     841.0     974.0
# 29  Andaman & Nicobar Islands     131.0     113.0     103.0     114.0
# 30                 Chandigarh       0.0     168.0     358.0     210.0
# 31       Dadra & Nagar Haveli      13.0      28.0      16.0      17.0
# 32              Daman and Diu      10.0       9.0       5.0       8.0
# 33                      Delhi       0.0       NaN       NaN       NaN
# 34                Lakshadweep       4.0       2.0       0.0       NaN
# 35                 Puducherry     487.0     756.0     572.0     359.0
# 36                      Total  160666.0  157545.0  174950.0  152332.0
#
#         2013      2014      2015      2016
# 0    12902.0   10485.0   13022.0   10540.0
# 1       84.0      83.0      88.0      71.0
# 2     2075.0    2629.0    2240.0    1708.0
# 3     3737.0    3826.0    3940.0    2061.0
# 4     3660.0    4628.0    6686.0    6827.0
# 5     2369.0    2286.0    2261.0    1528.0
# 6     9939.0    8012.0    8474.0    7896.0
# 7     4202.0    4177.0    4512.0    2771.0
# 8     1675.0    1809.0    2046.0     487.0
# 9     1267.0    1020.0    1040.0     611.0
# 10    3614.0    1951.0    2259.0    1874.0
# 11   18054.0   17936.0   17665.0   20187.0
# 12   16977.0   17497.0   18757.0   18950.0
# 13   21259.0   21608.0   22428.0   16570.0
# 14   32702.0   34437.0   19975.0   19863.0
# 15     290.0     463.0     402.0     203.0
# 16     153.0     117.0     186.0     133.0
# 17      15.0      31.0      12.0      22.0
# 18      21.0       NaN       5.0       0.0
# 19    4512.0    4734.0    4374.0    4322.0
# 20    1871.0    1941.0    2789.0    2207.0
# 21    5246.0    7516.0    7829.0    7786.0
# 22      64.0      63.0      51.0      59.0
# 23   35767.0   38094.0   36603.0   33149.0
# 24       NaN    5702.0   10359.0    5209.0
# 25     176.0     169.0     140.0     126.0
# 26     566.0     276.0     410.0     434.0
# 27   11238.0   13684.0   17191.0   13684.0
# 28    1287.0    2368.0    3674.0    3342.0
# 29      81.0      82.0      90.0      99.0
# 30     218.0       NaN       NaN       NaN
# 31       9.0      19.0      32.0      22.0
# 32      35.0      19.0      61.0      33.0
# 33       NaN       NaN    4399.0    1975.0
# 34       NaN       1.0       2.0       1.0
# 35    1017.0     561.0     769.0     745.0
# 36  197082.0  208224.0  214771.0  185495.0

# %%
df_ledu=pd.read_csv('Road accidents data/Accidents_Classified_Acc_To_EduQual_Of_Drivers_9-10_standard-09-16.csv')

# %%
df_ledu.head()
# Out:
#           States/UTs    2009    2010     2011    2012     2013    2014  \
# 0     Andhra Pradesh  9882.0  8040.0  13550.0  8657.0  17170.0  7941.0
# 1  Arunachal Pradesh   107.0    90.0    113.0    76.0    131.0    61.0
# 2              Assam  1704.0     NaN      NaN     NaN   2554.0  2547.0
# 3              Bihar  3273.0  5200.0   4136.0  3938.0   3761.0  3643.0
# 4       Chhattisgarh  6017.0  5994.0   6197.0  7052.0   7071.0  5041.0
#
#      2015    2016
# 0  6333.0  7111.0
# 1   104.0    69.0
# 2  2498.0  2936.0
# 3  2981.0  2400.0
# 4  5134.0  3626.0

# %%
df_hedu_updated=df_hedu.loc[:,['States/UTs','2016']]

# %%
df_hedu_updated=df_hedu_updated.rename(columns={'2016':'10th pass'})

# %%
df_hedu_updated
# Out:
#                    States/UTs  10th pass
# 0              Andhra Pradesh    10540.0
# 1           Arunachal Pradesh       71.0
# 2                       Assam     1708.0
# 3                       Bihar     2061.0
# 4                Chhattisgarh     6827.0
# 5                         Goa     1528.0
# 6                     Gujarat     7896.0
# 7                     Haryana     2771.0
# 8            Himachal Pradesh      487.0
# 9             Jammu & Kashmir      611.0
# 10                  Jharkhand     1874.0
# 11                  Karnataka    20187.0
# 12                     Kerala    18950.0
# 13             Madhya Pradesh    16570.0
# 14                Maharashtra    19863.0
# 15                    Manipur      203.0
# 16                  Meghalaya      133.0
# 17                    Mizoram       22.0
# 18                   Nagaland        0.0
# 19                     Odisha     4322.0
# 20                     Punjab     2207.0
# 21                  Rajasthan     7786.0
# 22                     Sikkim       59.0
# 23                 Tamil Nadu    33149.0
# 24                  Telangana     5209.0
# 25                    Tripura      126.0
# 26                Uttarakhand      434.0
# 27              Uttar Pradesh    13684.0
# 28                West Bengal     3342.0
# 29  Andaman & Nicobar Islands       99.0
# 30                 Chandigarh        NaN
# 31       Dadra & Nagar Haveli       22.0
# 32              Daman and Diu       33.0
# 33                      Delhi     1975.0
# 34                Lakshadweep        1.0
# 35                 Puducherry      745.0
# 36                      Total   185495.0

# %%
df_ledu_updated=df_ledu.loc[:,['2016']]

# %%
df_ledu_updated=df_ledu_updated.rename(columns={'2016': '10th Fail'})
df_ledu_updated
# Out:
#     10th Fail
# 0      7111.0
# 1        69.0
# 2      2936.0
# 3      2400.0
# 4      3626.0
# 5      2083.0
# 6      8086.0
# 7      2717.0
# 8      2180.0
# 9       780.0
# 10     1647.0
# 11    11372.0
# 12    14523.0
# 13    20210.0
# 14    11953.0
# 15      159.0
# 16      191.0
# 17       32.0
# 18        0.0
# 19     3572.0
# 20     2208.0
# 21     8382.0
# 22       68.0
# 23    23054.0
# 24     5583.0
# 25      291.0
# 26      527.0
# 27     7776.0
# 28     4101.0
# 29      115.0
# 30        NaN
# 31       35.0
# 32        9.0
# 33     1327.0
# 34        0.0
# 35      672.0
# 36   149795.0

# %%
df_education=df_hedu_updated.copy()

# %%
df_education['10th fail']=df_ledu_updated

# %%
df_education.dropna(axis=0,inplace=True)
df_education.drop(36,inplace=True)

# %%
plt.figure(figsize=(20,10))
sns.barplot(x=df_education['States/UTs'],y=df_education['10th pass'],palette='Paired')
plt.xticks(rotation=45,size=10)
plt.title('Drivers involved in road accidents who are 10th pass or above (2016)',size=25)
plt.ylabel('Number of accidents',size=15)
plt.xlabel('State/UT',size=15)
# Out:
# Text(0.5, 0, 'State/UT')

# %%
plt.figure(figsize=(20,10))
sns.barplot(x=df_education['States/UTs'],y=df_education['10th fail'])
plt.xticks(rotation=45,size=10)
plt.title('Drivers involved in road accidents who are not 10th pass (2016)',size=25)
plt.ylabel('Number of accidents',size=15)
plt.xlabel('State/UT',size=15)
# Out:
# Text(0.5, 0, 'State/UT')

# %% [markdown]
# From the above visualisations, it is observed that education plays little role in driver accidents. In Tamil Nadu, under both 10th pass and 10th fail criteria, the accidents are higher. The case is similar for most of the states. However, the cases in the North East states is extremely low even with limited road development due to it's challenging topological conditions.

# %%
df_education['Total accidents']=df_education['10th pass']+df_education['10th fail']
df_education.head()
# Out:
#           States/UTs  10th pass  10th fail  Total accidents
# 0     Andhra Pradesh    10540.0     7111.0          17651.0
# 1  Arunachal Pradesh       71.0       69.0            140.0
# 2              Assam     1708.0     2936.0           4644.0
# 3              Bihar     2061.0     2400.0           4461.0
# 4       Chhattisgarh     6827.0     3626.0          10453.0

# %%
df_education=df_education.sort_values(by='Total accidents',ascending=False)

# %%
df_age=pd.read_csv('Road accidents data/No_of_Road_Acc_acco_to_clf_of_age_of_Driver_2014_2016.csv')
df_age.head()
# Out:
#   S. No.          State/ UT  0-14  15-24  25-64  64 above  \
# 0      1     Andhra Pradesh   136   1812   4621       496
# 1      2  Arunachal Pradesh     0     30     16         0
# 2      3              Assam     0    252    237         0
# 3      4              Bihar    70    561    698       108
# 4      5       Chhattisgarh     0    432   1113         0
#
#    Age Less than 18 years - Fatal - 2016  \
# 0                                     91
# 1                                     11
# 2                                     84
# 3                                    557
# 4                                     81
#
#    Age Less than 18 years - Total - 2016  Age 18-25 - Fatal - 2016  \
# 0                                    436                      1682
# 1                                     32                        22
# 2                                    269                       765
# 3                                   1144                      1244
# 4                                    300                       778
#
#    Age 18-25 - Total - 2016  Age 25-35 - Fatal - 2016  \
# 0                      5751                      2148
# 1                        71                        21
# 2                      2774                       796
# 3                      2318                       941
# 4                      3120                      1127
#
#    Age 25-35 - Total - 2016  Age 35-45 - Fatal - 2016  \
# 0                      7034                      2316
# 1                        47                        19
# 2                      2188                       486
# 3                      1807                       724
# 4                      4209                       712
#
#    Age 35-45 - Total - 2016  Age 45-60 - Fatal - 2016  \
# 0                      6641                      1057
# 1                        35                        14
# 2                      1426                       183
# 3                      1281                       391
# 4                      2913                       383
#
#    Age 45-60 - Total - 2016  Age 60 and Above - Fatal - 2016  \
# 0                      3245                              150
# 1                        35                                0
# 2                       439                              131
# 3                       740                               65
# 4                      1522                               53
#
#    Age 60 and Above - Total - 2016  Age Age not known - Fatal - 2016  \
# 0                              416                               407
# 1                                0                                16
# 2                              339                                 0
# 3                              129                               503
# 4                              268                               393
#
#    Age Age not known - Total - 2016
# 0                              1365
# 1                                29
# 2                                 0
# 3                               803
# 4                              1248

# %%
df_age_2014=df_age.iloc[:,0:6]
df_age_2014.drop('S. No.',axis=1,inplace=True)

# %%
#df_age_2014.drop(36,inplace=True)
df_age_2014.dropna(axis=1,inplace=True)

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='State/ UT',y='0-14',data=df_age_2014)
plt.xticks(rotation=90)
plt.title('Drivers who are below the age of 14 and involved in accidents (2014)',size=25)
plt.xlabel('State/UTs',size=15)
plt.ylabel('Number of accidents',size=15)
# Out:
# Text(0, 0.5, 'Number of accidents')

# %% [markdown]
# From the above visualisation, the under age driving causing road accidents is extremely severe in Uttar Pradesh. Haryana,Telangana, West Bengal,Andhra Pradesh,Bihar,MP are also notable mentions. Under age driving punishments aren't enforced as strictly in these states as in other states.

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='State/ UT',y='15-24',data=df_age_2014,palette='gnuplot')
plt.xticks(rotation=90)
plt.title('Drivers who are of ages 15-24 and involved in accidents (2014)',size=25)
plt.xlabel('State/UTs',size=15)
plt.ylabel('Number of accidents',size=15)
# Out:
# Text(0, 0.5, 'Number of accidents')

# %% [markdown]
# Between the ages of 15-24, most of the accidents are from Maharashtra and UP. Telangana, Andhra Pradesh, Karnataka are also a notable mention. This age group generally comprises of school going senior students or college students who use 2 wheelers. Speeding is one of the major reasons for these accidents.

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='State/ UT',y='25-64',data=df_age_2014)
plt.xticks(rotation=90)
plt.title('Drivers who are of ages 25-64 and involved in accidents (2014)',size=25)
plt.xlabel('State/UTs',size=15)
plt.ylabel('Number of accidents',size=15)
# Out:
# Text(0, 0.5, 'Number of accidents')

# %% [markdown]
# Amongst the middle aged and retiring aged people, Andhra Pradesh , Telangana, Tamil Nadu , Maharashtra have high cases of accidents.

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='State/ UT',y='64 above',data=df_age_2014,palette='Spectral')
plt.xticks(rotation=90)
plt.title('Drivers who are of ages 64 above and involved in accidents (2014)',size=25)
plt.xlabel('State/UTs',size=15)
plt.ylabel('Number of accidents',size=15)
# Out:
# Text(0, 0.5, 'Number of accidents')

# %% [markdown]
# Amongst the senior citizens aswell, Andhra Pradesh records the highest cases followed by MP and UP. States having strong public transport systems such as metros and buses show low accident rates for senior citizens since they prefer it over driving themselves.

# %%
df_Andhra=df_age_2014.iloc[0:1,:]

# %%
df_Andhra
# Out:
#         State/ UT  0-14  15-24  25-64  64 above
# 0  Andhra Pradesh   136   1812   4621       496

# %%
unstack_df=df_Andhra.unstack()

# %%
unstack_df.reset_index(drop=True,inplace=True)

# %%
list1=[]
for i in range(1,5):
    list1.append(unstack_df[i])
    i+=1

# %%
labels=['0-14','15-24','25-64','64 above']

# %%
plt.figure(figsize=(10,10))
plt.pie(list1,labels=labels,autopct='%1.1f%%')
plt.title('Road accidents in Andhra Pradesh by age groups (2014)',size=20)
# Out:
# Text(0.5, 1.0, 'Road accidents in Andhra Pradesh by age groups (2014)')

# %%
df_maha=df_age_2014.loc[14:14,:]

# %%
df_maha
# Out:
#       State/ UT  0-14  15-24  25-64  64 above
# 14  Maharashtra     0   2323   3490         1

# %%
unstack_df=df_maha.unstack()

unstack_df.reset_index(drop=True,inplace=True)

list1=[]
for i in range(1,5):
    list1.append(unstack_df[i])
    i+=1

# %%
plt.figure(figsize=(10,10))
plt.pie(list1,labels=labels,autopct='%1.1f%%')
plt.title('Road accidents in Maharashtra by age groups (2014)',size=20)
# Out:
# Text(0.5, 1.0, 'Road accidents in Maharashtra by age groups (2014)')

# %% [markdown]
# In Maharashtra, no accidents are caused by underage driving or by senior citizens. This indicates strict traffic and police regulations against under age driving.

# %%
df_Kar=df_age_2014.copy()

# %%
df_Kar=df_Kar.iloc[11:12,:]
df_Kar
# Out:
#     State/ UT  0-14  15-24  25-64  64 above
# 11  Karnataka    14   1700   1517       241

# %%
unstack_df=df_Kar.unstack()

# %%
unstack_df.reset_index(drop=True,inplace=True)

# %%
list1=[]
for i in range(1,5):
    list1.append(unstack_df[i])
    i+=1

# %%
plt.figure(figsize=(10,10))
plt.pie(list1,labels=labels,autopct='%1.1f%%')
plt.title('Road accidents in Karnataka by age groups (2014)',size=20)
# Out:
# Text(0.5, 1.0, 'Road accidents in Karnataka by age groups (2014)')

# %%
df_time=pd.read_csv('Road accidents data/only_road_accidents_data3.csv')

# %%
df_time=df_time.reset_index(drop=True)
df_time.head()
# Out:
#         STATE/UT  YEAR  0-3 hrs. (Night)  3-6 hrs. (Night)  6-9 hrs (Day)  \
# 0  A & N Islands  2001                 2                 6             29
# 1  A & N Islands  2002                 2                 6             22
# 2  A & N Islands  2003                 2                 8             31
# 3  A & N Islands  2004                 2                 5             29
# 4  A & N Islands  2005                 0                 8             27
#
#    9-12 hrs (Day)  12-15 hrs (Day)  15-18 hrs (Day)  18-21 hrs (Night)  \
# 0              40               39               40                 18
# 1              41               33               33                 23
# 2              35               28               36                 25
# 3              42               43               43                 37
# 4              28               38               42                 50
#
#    21-24 hrs (Night)  Total
# 0                  7    181
# 1                  8    168
# 2                 15    180
# 3                 14    215
# 4                 13    206

# %%
df_time=df_time.loc[df_time['YEAR'].isin(['2014'])]

# %%
df_time
# Out:
#               STATE/UT  YEAR  0-3 hrs. (Night)  3-6 hrs. (Night)  \
# 13       A & N Islands  2014                 4                 6
# 27      Andhra Pradesh  2014              3336              4466
# 41   Arunachal Pradesh  2014                 6                 5
# 55               Assam  2014               212               277
# 69               Bihar  2014               672               987
# 83          Chandigarh  2014                32                29
# 97        Chhattisgarh  2014               648               849
# 111       D & N Haveli  2014                 1                 1
# 125        Daman & Diu  2014                 3                 0
# 139         Delhi (Ut)  2014               757               581
# 153                Goa  2014               189               173
# 167            Gujarat  2014              1232              1541
# 181            Haryana  2014               726               868
# 195   Himachal Pradesh  2014               199               183
# 209    Jammu & Kashmir  2014               168               442
# 223          Jharkhand  2014               247               592
# 237          Karnataka  2014              3022              3219
# 251             Kerala  2014               759              1232
# 265        Lakshadweep  2014                 0                 0
# 279     Madhya Pradesh  2014              1925              2384
# 293        Maharashtra  2014              3376              3330
# 307            Manipur  2014                 7                 8
# 321          Meghalaya  2014                10                19
# 335            Mizoram  2014                 5                12
# 349           Nagaland  2014                 0                 2
# 363             Odisha  2014               661               880
# 377         Puducherry  2014                28                23
# 391             Punjab  2014               387               392
# 405          Rajasthan  2014              1128              1428
# 419             Sikkim  2014                 6                 8
# 433         Tamil Nadu  2014              2685              4057
# 447            Tripura  2014                15                21
# 461      Uttar Pradesh  2014              2106              2824
# 475        Uttarakhand  2014                61                81
# 489        West Bengal  2014              1455              1634
#
#      6-9 hrs (Day)  9-12 hrs (Day)  12-15 hrs (Day)  15-18 hrs (Day)  \
# 13              25              28               55               36
# 27            4312            5631             5882             6669
# 41              13              24               26               45
# 55             939            1475             1225             1438
# 69            1429            1429             1460             1421
# 83              42              51               41               56
# 97            1469            1916             1702             2102
# 111              8               7               13               22
# 125              4               6                5                7
# 139            867             925              909             1208
# 153            371             712              752              791
# 167           2496            3595             3328             3735
# 181           1459            1646             1493             1740
# 195            418             517              517              603
# 209            693             928             1195             1126
# 223            703             749              670              847
# 237           4576            6393             6646             7119
# 251           4145            6709             6057             8172
# 265              0               0                1                0
# 279           5370            7106             7337             7030
# 293           4853            6430             6522             7126
# 307             47             162              148              173
# 321             30              45               59               55
# 335             11               9               11               20
# 349              3               3                8                6
# 363           1099            1413             1283             1651
# 377             58             109               97              179
# 391            683             842              943              998
# 405           2622            3706             4234             4841
# 419             15              17               12               27
# 433           7973            9593             9955            11902
# 447             53             199              123              161
# 461           3376            3547             3522             3929
# 475             95             122              117              137
# 489           2022            2998             2570             2458
#
#      18-21 hrs (Night)  21-24 hrs (Night)  Total
# 13                  41                 23    218
# 27                7177               5759  43232
# 41                  36                 30    185
# 55                1023                555   7144
# 69                1262                871   9531
# 83                  66                 49    366
# 97                2072               1382  12140
# 111                 27                  8     87
# 125                 12                  2     39
# 139               1502               1561   8310
# 153                785                457   4230
# 167               3791               2434  22152
# 181               1887               1224  11043
# 195                558                330   3325
# 209                833                393   5778
# 223                678                419   4905
# 237               7377               5342  43694
# 251               6114               2684  35872
# 265                  0                  0      1
# 279               5791               2755  39698
# 293               7421               5324  44382
# 307                141                 49    735
# 321                 50                 33    301
# 335                 15                 12     95
# 349                  5                  1     28
# 363               1564               1089   9640
# 377                115                 62    671
# 391               1380                766   6391
# 405               4215               2465  24639
# 419                 29                 16    130
# 433              13927               7158  67250
# 447                 96                 48    716
# 461               4099               2661  26064
# 475                113                 75    801
# 489               2132               1836  17105

# %%
df_time_top=df_time[df_time['Total']>40000]
df_time_top.reset_index(drop=True,inplace=True)

# %%
df_time_Andhra=df_time_top.loc[0:0,:]
df_time_Andhra
# Out:
#          STATE/UT  YEAR  0-3 hrs. (Night)  3-6 hrs. (Night)  6-9 hrs (Day)  \
# 0  Andhra Pradesh  2014              3336              4466           4312
#
#    9-12 hrs (Day)  12-15 hrs (Day)  15-18 hrs (Day)  18-21 hrs (Night)  \
# 0            5631             5882             6669               7177
#
#    21-24 hrs (Night)  Total
# 0               5759  43232

# %%
unstack_df=df_time_Andhra.unstack()
unstack_df.reset_index(drop=True,inplace=True)
unstack_df
# Out:
# 0     Andhra Pradesh
# 1               2014
# 2               3336
# 3               4466
# 4               4312
# 5               5631
# 6               5882
# 7               6669
# 8               7177
# 9               5759
# 10             43232
# dtype: object

# %%
labels=['0-3','3-6','6-9','9-12','12-15','15-18','18-21','21-24']

# %%
list1=[]
for i in range(2,10):
    list1.append(unstack_df[i])
    i+=1

# %%
plt.figure(figsize=(10,10))
plt.pie(list1,labels=labels,autopct='%1.1f%%')
plt.title('Road accidents in Andhra Pradesh by time of accident in hrs (2014)',size=20)
# Out:
# Text(0.5, 1.0, 'Road accidents in Andhra Pradesh by time of accident in hrs (2014)')

# %% [markdown]
# From the above, it can be seen that the accidents occuring from 18-21 hrs is slightly higher. Most of the accidents occur after sunset when the visibility might be low. This means drivers are facing issues with inadequate lighting or rash fellow drivers. Strict police patrolling to maintain speed limits could definitely help reduce accidents.

# %%
df_time_Kar=df_time_top.loc[1:1,:]
df_time_Kar

unstack_df=df_time_Kar.unstack()
unstack_df.reset_index(drop=True,inplace=True)
unstack_df
# Out:
# 0     Karnataka
# 1          2014
# 2          3022
# 3          3219
# 4          4576
# 5          6393
# 6          6646
# 7          7119
# 8          7377
# 9          5342
# 10        43694
# dtype: object

# %%
list1=[]
for i in range(2,10):
    list1.append(unstack_df[i])
    i+=1

# %%
plt.figure(figsize=(10,10))
plt.pie(list1,labels=labels,autopct='%1.1f%%')
plt.title('Road accidents in Karanataka by time of accident in hrs (2014)',size=20)
# Out:
# Text(0.5, 1.0, 'Road accidents in Karanataka by time of accident in hrs (2014)')

# %%
df_time_TN=df_time_top.loc[3:3,:]
df_time_TN
# Out:
#      STATE/UT  YEAR  0-3 hrs. (Night)  3-6 hrs. (Night)  6-9 hrs (Day)  \
# 3  Tamil Nadu  2014              2685              4057           7973
#
#    9-12 hrs (Day)  12-15 hrs (Day)  15-18 hrs (Day)  18-21 hrs (Night)  \
# 3            9593             9955            11902              13927
#
#    21-24 hrs (Night)  Total
# 3               7158  67250

# %%
unstack_df=df_time_TN.unstack()
unstack_df.reset_index(drop=True,inplace=True)
unstack_df
# Out:
# 0     Tamil Nadu
# 1           2014
# 2           2685
# 3           4057
# 4           7973
# 5           9593
# 6           9955
# 7          11902
# 8          13927
# 9           7158
# 10         67250
# dtype: object

# %%
list1=[]
for i in range(2,10):
    list1.append(unstack_df[i])
    i+=1

# %%
plt.figure(figsize=(10,10))
plt.pie(list1,labels=labels,autopct='%1.1f%%')
plt.title('Road accidents in Tamil Nadu by time of accident in hrs (2014)',size=20)
# Out:
# Text(0.5, 1.0, 'Road accidents in Tamil Nadu by time of accident in hrs (2014)')
